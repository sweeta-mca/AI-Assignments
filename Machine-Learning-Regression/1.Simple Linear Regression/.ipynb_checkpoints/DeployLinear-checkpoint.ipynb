# %%
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
# load the model from the file 
filename="finalized_model.sav"
pickle_in = open(filename,"rb")
model=pickle.load(pickle_in)
pickle_in.close()

# %%
prediction_input=int(input("Enter the Prediction input value:"))
# Out:
# Enter the Prediction input value: 14

# %%
Future_Prediction=model.predict([[prediction_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[[157659.38644774]]
